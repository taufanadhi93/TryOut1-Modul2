# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('2019.csv')
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# Finding Central of Data Generosity

genInfo  = df['Generosity'].agg(Min=np.min, Max=np.max, Mean=np.mean, Median=np.median)
genMin   = df['Generosity'].min()
genMax   = df['Generosity'].max()
genMean  = df['Generosity'].mean()
genMedian= df['Generosity'].median()
genMode  = df['Generosity'].mode()


# Finding Distribution of Generosity Data

genSTD   = df['Generosity'].std()
genVAR   = df['Generosity'].var()
genQ1    = np.quantile(df['Generosity'],0.25)
genQ3    = np.quantile(df['Generosity'],0.75)
genIQR   = genQ3-genQ1
genLower = genQ1-(1.5*genIQR)
genUpper = genQ3+(1.5*genIQR)
genRange = genMax - genMin

print('Standard Deviation: ',genSTD)
print('Standard Variation: ',genVAR)
print('Q1                : ',genQ1)
print('Q3                : ',genQ3)
print('IQR               : ',genIQR)
# Out:
# Standard Deviation:  0.09525444050922018
# Standard Variation:  0.009073408436724564
# Q1                :  0.10875
# Q3                :  0.24825
# IQR               :  0.1395

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.histplot(df['Generosity'])
ax.set_title('Generosity Distribution')
ax.set_xlabel('Generosity')
ax.set_ylabel('Frequency')

ax.axvline(x=genMean, label='Mean', color='r')
ax.axvline(x=genMedian, label='Median', color='b')
ax.legend()

plt.show()

# %%
# Finding Central of Perception of corruption

perInfo  = df['Perceptions of corruption'].agg(Min=np.min, Max=np.max, Mean=np.mean, Median=np.median)
perMin   = df['Perceptions of corruption'].min()
perMax   = df['Perceptions of corruption'].max()
perMean  = df['Perceptions of corruption'].mean()
perMedian= df['Perceptions of corruption'].median()
perMode  = df['Perceptions of corruption'].mode()

# Finding Distribution of Perceptions of corruption Data

perSTD   = df['Perceptions of corruption'].std()
perVAR   = df['Perceptions of corruption'].var()
perQ1    = np.quantile(df['Perceptions of corruption'],0.25)
perQ3    = np.quantile(df['Perceptions of corruption'],0.75)
perIQR   = genQ3-genQ1
perLower = perQ1-(1.5*perIQR)
perUpper = perQ3+(1.5*perIQR)
perRange = perMax - perMin

print('Standard Deviation: ',perSTD)
print('Standard Variation: ',perVAR)
print('Q1                : ',perQ1)
print('Q3                : ',perQ3)
print('IQR               : ',perIQR)
print('Lower             : ',perLower)
print('Upper             : ',perUpper)
# Out:
# Standard Deviation:  0.09453783536745279
# Standard Variation:  0.008937402315963607
# Q1                :  0.047
# Q3                :  0.14125
# IQR               :  0.1395
# Lower             :  -0.16225
# Upper             :  0.35050000000000003

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.boxplot(data=df,x='Perceptions of corruption')
ax.set_xlabel('Perceptions of corruption Value')
plt.show()

# %%
# Data Dispersion

fig, ax = plt.subplots(figsize=(10,8))
sns.histplot(df['Perceptions of corruption'])
ax.set_title('Perceptions of corruption Distribution')
ax.set_xlabel('Perceptions of corruption')
ax.set_ylabel('Frequency')

ax.axvline(x=perMean, label='Mean', color='r')
ax.axvline(x=perMedian, label='Median', color='b')
ax.legend()

plt.show()

# %%
# Finding Central of Social support
sosMin   = df['Social support'].min()
sosMax   = df['Social support'].max()
sosMean  = df['Social support'].mean()
sosMedian= df['Social support'].median()
sosMode  = df['Social support'].mode()

# Finding Distribution of Social support Data

sosSTD   = df['Social support'].std()
sosVAR   = df['Social support'].var()
sosQ1    = np.quantile(df['Social support'],0.25)
sosQ3    = np.quantile(df['Social support'],0.75)
sosIQR   = sosQ3-sosQ1
sosLower = sosQ1-(1.5*sosIQR)
sosUpper = sosQ3+(1.5*sosIQR)
sosRange = sosMax - sosMin

df[(df['Social support']<=sosLower)|(df['Social support']>=sosUpper)]
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 101           102                     Benin  4.883           0.393
# 144           145                   Burundi  3.775           0.046
# 148           149                     Syria  3.462           0.619
# 154           155  Central African Republic  3.083           0.026
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 101           0.437                    0.397                         0.349
# 144           0.447                    0.380                         0.220
# 148           0.378                    0.440                         0.013
# 154           0.000                    0.105                         0.225
#
#      Generosity  Perceptions of corruption
# 101       0.175                      0.082
# 144       0.176                      0.180
# 148       0.331                      0.141
# 154       0.235                      0.035

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.boxplot(data=df,x='Social support')
ax.set_xlabel('Social support')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.histplot(df['Freedom to make life choices'])
ax.set_title('Freedom to make life choices')
ax.set_xlabel('Freedom to make life choices')
ax.set_ylabel('Frequency')
plt.show()

# %%
df2 = df[['GDP per capita', 'Social support', 'Healthy life expectancy']]
df2.head(5)
# Out:
#    GDP per capita  Social support  Healthy life expectancy
# 0           1.340           1.587                    0.986
# 1           1.383           1.573                    0.996
# 2           1.488           1.582                    1.028
# 3           1.380           1.624                    1.026
# 4           1.396           1.522                    0.999

# %%
score_pearson = pd.DataFrame(df2.corrwith(df['Score'],method='pearson'),columns=['Score'])
score_pearson

#both variable are quantitative and the relation between variables is linear
#since GDP per capita has the biggest correlation, government should focusing on increasing economic growth, for example increasing the number of export, increasing human resource quality by supporting greater education
# Out:
#                             Score
# GDP per capita           0.793883
# Social support           0.777058
# Healthy life expectancy  0.779883

# %%
score_spearman = pd.DataFrame(df2.corrwith(df['Score'],method='spearman'),columns=['Score'])
score_spearman
# Out:
#                             Score
# GDP per capita           0.814483
# Social support           0.816181
# Healthy life expectancy  0.807275

# %%
scMean=df['Score'].mean()
df3 = df[(df['Score']>scMean)][['Country or region', 'GDP per capita']].sort_values('GDP per capita', ascending=False).head(5)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(data=df3, x=df3['Country or region'], y=df3['GDP per capita'])
ax.set_title('Top 5 "GDP per capita" Country ')
ax.set_xlabel('Country or region')
ax.set_ylabel('GDP per capita')
plt.show()

# %%
scMean=df['Score'].mean()
df4 = df[(df['Score']>scMean)][['Country or region', 'Generosity']].sort_values('Generosity', ascending=False).tail(5)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(data=df4, x=df4['Country or region'], y=df4['Generosity'])
ax.set_title('Top 5 Bottom "Generosity" Country ')
ax.set_xlabel('Country or region')
ax.set_ylabel('Generosity')
plt.show()

# %%
scMean=df['Score'].mean()
df5 = df[(df['Score']>scMean)][['Country or region', 'Perceptions of corruption']].sort_values('Perceptions of corruption', ascending=False).tail(5)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.barplot(data=df5, x=df5['Country or region'], y=df5['Perceptions of corruption'],)
ax.set_title('Top 5 Bottom "Perceptions of corruption" Country ')
ax.set_xlabel('Country or region')
ax.set_ylabel('Perceptions of corruption')
plt.show()
